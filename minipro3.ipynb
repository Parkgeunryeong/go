# %% [markdown]
# <a href="https://colab.research.google.com/github/Parkgeunryeong/go/blob/master/minipro3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, cv2, random
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from google.colab import drive
drive.mount('/content/drive')

# 드라이브에서 데이터셋과 카테고리를 나누는 코드
dir_path = '/content/drive/MyDrive/dog_dataset'
categories = [
    'Beagle', 'Boxer', 'Bulldog', 'Dachshund', 'German_Shepherd', 'Golden_Retriever', 'Labrador_Retriever', 'Poodle', 'Rottweiler', 'Yorkshire_Terrier'
] # 클래스 수는 총 10개

# 이미지 로딩 및 전처리
data = []
for i in categories: #폴더 별로 데이터를 가져와서 폴더 명칭을 라벨로 예) Beagle은 0으로 라벨링...Boxer은 1로 라벨링...
    path = os.path.join(dir_path, i)
    label = categories.index(i)
    for img_name in os.listdir(path): # 각 폴더안에 들어있는 사진 데이터 전처리
        img_path = os.path.join(path, img_name)
        if os.path.splitext(img_path)[1].lower() == '.jpg': #.jpg파일만 가져오기
            img = cv2.imread(img_path)
            img = cv2.resize(img, (32, 32)) #이미지를 32,32사이즈로 변경
            data.append([img, label])

random.shuffle(data)

# 정규화 및 전처리
x = []
y = []
for features, label in data: #x에는 사진데이터 값, y는 라벨값
    x.append(features)
    y.append(label)

x = np.array(x) / 255.0 #0~255사이의 픽셀값을 0~1로 정규화
y = np.array(y)
x = x.reshape(-1, 32, 32, 3) #32,32로 다시 reshape

# 학습용 80%, 테스트용 20%로 분리
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, shuffle=True
)
#데이터 증가를 위한 부분
datagen = ImageDataGenerator(
    validation_split=0.2,  # 학습용 데이터중 20%를 검증셋에 이용
    rotation_range=30, #회전 30도까지
    width_shift_range=0.2,#좌우 이동
    zoom_range=[0.8, 1.2] #확대
)
#데이터 증가를 사용하기위한 제네레이터(학습데이터)
train_generator = datagen.flow(
    X_train, y_train,
    batch_size=20,
    subset='training'
)
#데이터 증가를 사용하기 위한 제네레이터(검증데이터)
val_generator = datagen.flow(
    X_train, y_train,
    batch_size=20,
    subset='validation'
)


# 모델 구성
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))  # 10개의 카테고리 분류 (다중분류 이므로 softmax사용)
model.summary() #모델 구조 보여주는 함수

# 과적합 방지를 위한 early_stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=30)
checkpointer = ModelCheckpoint(filepath='/content/dog_model_best.keras', monitor='val_loss', save_best_only=True)

# 컴파일 및 학습
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_generator, validation_data=val_generator, epochs=200, callbacks=[early_stopping, checkpointer])

# 평가
score = model.evaluate(X_test, y_test)
print("전체 데이터 정확도:", score[1])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │         5,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 361,034 (1.38 MB)
#  Trainable params: 361,034 (1.38 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.0869 - loss: 2.3190 - val_accuracy: 0.1429 - val_loss: 2.2930
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.1110 - loss: 2.2885 - val_accuracy: 0.2143 - val_loss: 2.1996
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.1917 - loss: 2.1817 - val_accuracy: 0.1688 - val_loss: 2.1686
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.2255 - loss: 2.1112 - val_accuracy: 0.2013 - val_loss: 2.0566
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.2723 - loss: 2.0172 - val_accuracy: 0.2208 - val_loss: 1.9714
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3388 - loss: 1.9193 - val_accuracy: 0.2532 - val_loss: 1.9020
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.3429 - loss: 1.8620 - val_accuracy: 0.2987 - val_loss: 1.9200
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.3864 - loss: 1.7466 - val_accuracy: 0.3442 - val_loss: 1.7780
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.4401 - loss: 1.6327 - val_accuracy: 0.4026 - val_loss: 1.6352
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4578 - loss: 1.5803 - val_accuracy: 0.4481 - val_loss: 1.5169
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5091 - loss: 1.4048 - val_accuracy: 0.4221 - val_loss: 1.5679
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.5557 - loss: 1.3049 - val_accuracy: 0.4675 - val_loss: 1.4075
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.5870 - loss: 1.1680 - val_accuracy: 0.5195 - val_loss: 1.2618
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5629 - loss: 1.1444 - val_accuracy: 0.4805 - val_loss: 1.2108
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6860 - loss: 0.9383 - val_accuracy: 0.6688 - val_loss: 1.0908
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7381 - loss: 0.8491 - val_accuracy: 0.5974 - val_loss: 1.0803
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7154 - loss: 0.8526 - val_accuracy: 0.6429 - val_loss: 1.0593
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7563 - loss: 0.7358 - val_accuracy: 0.7273 - val_loss: 0.8931
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.7962 - loss: 0.6821 - val_accuracy: 0.6818 - val_loss: 0.9276
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8109 - loss: 0.6332 - val_accuracy: 0.7468 - val_loss: 0.7485
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8215 - loss: 0.5414 - val_accuracy: 0.7013 - val_loss: 0.9473
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8188 - loss: 0.6309 - val_accuracy: 0.7468 - val_loss: 0.6457
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8449 - loss: 0.4515 - val_accuracy: 0.8377 - val_loss: 0.5294
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.8590 - loss: 0.4250 - val_accuracy: 0.7987 - val_loss: 0.6014
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8626 - loss: 0.4410 - val_accuracy: 0.7987 - val_loss: 0.5625
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8822 - loss: 0.4003 - val_accuracy: 0.8117 - val_loss: 0.6211
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8912 - loss: 0.3635 - val_accuracy: 0.8442 - val_loss: 0.5098
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8904 - loss: 0.3299 - val_accuracy: 0.8701 - val_loss: 0.3764
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9075 - loss: 0.2635 - val_accuracy: 0.8831 - val_loss: 0.3492
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9187 - loss: 0.2392 - val_accuracy: 0.8896 - val_loss: 0.3544
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9361 - loss: 0.2305 - val_accuracy: 0.8896 - val_loss: 0.3142
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9302 - loss: 0.2261 - val_accuracy: 0.8506 - val_loss: 0.4587
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8734 - loss: 0.3660 - val_accuracy: 0.9221 - val_loss: 0.3614
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9165 - loss: 0.2385 - val_accuracy: 0.9091 - val_loss: 0.2960
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9358 - loss: 0.2062 - val_accuracy: 0.9156 - val_loss: 0.2541
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9391 - loss: 0.1891 - val_accuracy: 0.9026 - val_loss: 0.3307
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9376 - loss: 0.2101 - val_accuracy: 0.9351 - val_loss: 0.2042
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9489 - loss: 0.1755 - val_accuracy: 0.9026 - val_loss: 0.3473
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9269 - loss: 0.1866 - val_accuracy: 0.9221 - val_loss: 0.1771
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9492 - loss: 0.1723 - val_accuracy: 0.9675 - val_loss: 0.1245
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9599 - loss: 0.1489 - val_accuracy: 0.9156 - val_loss: 0.2420
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9219 - loss: 0.2231 - val_accuracy: 0.8831 - val_loss: 0.2908
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9612 - loss: 0.1547 - val_accuracy: 0.9610 - val_loss: 0.1330
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9551 - loss: 0.1280 - val_accuracy: 0.9610 - val_loss: 0.1123
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9697 - loss: 0.1085 - val_accuracy: 0.9805 - val_loss: 0.1144
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9725 - loss: 0.0979 - val_accuracy: 0.9610 - val_loss: 0.1375
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9545 - loss: 0.1524 - val_accuracy: 0.9740 - val_loss: 0.1254
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9665 - loss: 0.1323 - val_accuracy: 0.9545 - val_loss: 0.1290
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9695 - loss: 0.0868 - val_accuracy: 0.9481 - val_loss: 0.1340
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9702 - loss: 0.1036 - val_accuracy: 0.9286 - val_loss: 0.1575
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9551 - loss: 0.1146 - val_accuracy: 0.9805 - val_loss: 0.0684
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9704 - loss: 0.0773 - val_accuracy: 0.9675 - val_loss: 0.1061
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9609 - loss: 0.0840 - val_accuracy: 0.9740 - val_loss: 0.0835
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9739 - loss: 0.1055 - val_accuracy: 0.9091 - val_loss: 0.2144
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9778 - loss: 0.1028 - val_accuracy: 0.9675 - val_loss: 0.1207
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9736 - loss: 0.0880 - val_accuracy: 0.9740 - val_loss: 0.0751
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9686 - loss: 0.0801 - val_accuracy: 0.9675 - val_loss: 0.1269
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9737 - loss: 0.0843 - val_accuracy: 0.9805 - val_loss: 0.0721
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9513 - loss: 0.1161 - val_accuracy: 0.9545 - val_loss: 0.1352
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9537 - loss: 0.1518 - val_accuracy: 0.9805 - val_loss: 0.0920
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9750 - loss: 0.0872 - val_accuracy: 0.9870 - val_loss: 0.0617
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9696 - loss: 0.0775 - val_accuracy: 0.9675 - val_loss: 0.0770
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9690 - loss: 0.0821 - val_accuracy: 0.9740 - val_loss: 0.0716
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9853 - loss: 0.0561 - val_accuracy: 0.9740 - val_loss: 0.0957
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9854 - loss: 0.0427 - val_accuracy: 0.9805 - val_loss: 0.0690
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9621 - loss: 0.1101 - val_accuracy: 0.9805 - val_loss: 0.0862
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9913 - loss: 0.0482 - val_accuracy: 0.9805 - val_loss: 0.0616
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9702 - loss: 0.0853 - val_accuracy: 0.9935 - val_loss: 0.0408
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9865 - loss: 0.0790 - val_accuracy: 0.9870 - val_loss: 0.0780
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9783 - loss: 0.0693 - val_accuracy: 0.9675 - val_loss: 0.1298
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9547 - loss: 0.0916 - val_accuracy: 0.9805 - val_loss: 0.1057
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9737 - loss: 0.0657 - val_accuracy: 0.9935 - val_loss: 0.0406
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9770 - loss: 0.0770 - val_accuracy: 0.9351 - val_loss: 0.2435
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9644 - loss: 0.1119 - val_accuracy: 0.9221 - val_loss: 0.2766
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9596 - loss: 0.0999 - val_accuracy: 0.9545 - val_loss: 0.1061
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9923 - loss: 0.0484 - val_accuracy: 0.9870 - val_loss: 0.0649
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9814 - loss: 0.0518 - val_accuracy: 0.9740 - val_loss: 0.1188
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9836 - loss: 0.0688 - val_accuracy: 0.9870 - val_loss: 0.0851
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9722 - loss: 0.0758 - val_accuracy: 0.9481 - val_loss: 0.1227
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9786 - loss: 0.0720 - val_accuracy: 0.9870 - val_loss: 0.0620
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9938 - loss: 0.0348 - val_accuracy: 0.9610 - val_loss: 0.0997
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9874 - loss: 0.0454 - val_accuracy: 0.9805 - val_loss: 0.1220
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9718 - loss: 0.0658 - val_accuracy: 0.9935 - val_loss: 0.0405
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9795 - loss: 0.0601 - val_accuracy: 0.9870 - val_loss: 0.0744
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9862 - loss: 0.0428 - val_accuracy: 0.9805 - val_loss: 0.0938
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9994 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.0219
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9961 - loss: 0.0163 - val_accuracy: 0.9870 - val_loss: 0.0336
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9698 - loss: 0.0946 - val_accuracy: 0.9481 - val_loss: 0.1442
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9698 - loss: 0.1230 - val_accuracy: 0.9740 - val_loss: 0.0692
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9847 - loss: 0.0642 - val_accuracy: 0.9740 - val_loss: 0.0555
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9926 - loss: 0.0242 - val_accuracy: 0.9805 - val_loss: 0.0369
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9926 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0166
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9827 - loss: 0.0927 - val_accuracy: 0.9740 - val_loss: 0.0699
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9960 - loss: 0.0207 - val_accuracy: 0.9870 - val_loss: 0.0262
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9927 - loss: 0.0237 - val_accuracy: 0.9675 - val_loss: 0.1268
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9775 - loss: 0.0943 - val_accuracy: 0.9675 - val_loss: 0.0952
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9795 - loss: 0.0663 - val_accuracy: 0.9740 - val_loss: 0.0869
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9949 - loss: 0.0330 - val_accuracy: 0.9935 - val_loss: 0.0364
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9865 - loss: 0.0519 - val_accuracy: 0.9805 - val_loss: 0.0754
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9810 - loss: 0.0796 - val_accuracy: 0.9351 - val_loss: 0.2098
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9855 - loss: 0.0561 - val_accuracy: 0.9870 - val_loss: 0.0248
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9916 - loss: 0.0265 - val_accuracy: 0.9805 - val_loss: 0.0531
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9792 - loss: 0.0565 - val_accuracy: 0.9805 - val_loss: 0.0658
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9882 - loss: 0.0377 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9864 - loss: 0.0413 - val_accuracy: 0.9935 - val_loss: 0.0225
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9914 - loss: 0.0180 - val_accuracy: 0.9935 - val_loss: 0.0198
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9883 - loss: 0.0320 - val_accuracy: 0.9805 - val_loss: 0.0302
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9661 - loss: 0.1089 - val_accuracy: 0.9675 - val_loss: 0.1063
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9829 - loss: 0.0653 - val_accuracy: 0.9740 - val_loss: 0.0541
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9601 - loss: 0.1300 - val_accuracy: 0.9935 - val_loss: 0.0365
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9979 - loss: 0.0333 - val_accuracy: 0.9870 - val_loss: 0.0531
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9886 - loss: 0.0396 - val_accuracy: 0.9935 - val_loss: 0.0536
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9693 - loss: 0.0550 - val_accuracy: 0.9935 - val_loss: 0.0643
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9956 - loss: 0.0212 - val_accuracy: 0.9935 - val_loss: 0.0453
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9974 - loss: 0.0157 - val_accuracy: 0.9935 - val_loss: 0.0236
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9900 - loss: 0.0213 - val_accuracy: 0.9805 - val_loss: 0.0606
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9930 - loss: 0.0262 - val_accuracy: 0.9935 - val_loss: 0.0142
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9922 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9973 - loss: 0.0198 - val_accuracy: 0.9935 - val_loss: 0.0188
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9952 - loss: 0.0186 - val_accuracy: 0.9935 - val_loss: 0.0417
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9904 - loss: 0.0197 - val_accuracy: 0.9935 - val_loss: 0.0384
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9842 - loss: 0.0408 - val_accuracy: 0.9675 - val_loss: 0.0860
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9779 - loss: 0.0414 - val_accuracy: 0.9870 - val_loss: 0.0587
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9804 - loss: 0.0708 - val_accuracy: 0.9610 - val_loss: 0.1467
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9926 - loss: 0.0431 - val_accuracy: 0.9545 - val_loss: 0.1495
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9695 - loss: 0.0822 - val_accuracy: 0.9805 - val_loss: 0.1088
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9649 - loss: 0.1122 - val_accuracy: 0.9675 - val_loss: 0.0878
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9652 - loss: 0.0914 - val_accuracy: 0.9675 - val_loss: 0.0914
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9811 - loss: 0.0541 - val_accuracy: 0.9805 - val_loss: 0.0959
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9835 - loss: 0.0338 - val_accuracy: 0.9740 - val_loss: 0.0473
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9784 - loss: 0.0459 - val_accuracy: 0.9935 - val_loss: 0.0419
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9903 - loss: 0.0303 - val_accuracy: 0.9740 - val_loss: 0.0880
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9931 - loss: 0.0257 - val_accuracy: 0.9870 - val_loss: 0.0443
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9920 - loss: 0.0318 - val_accuracy: 0.9870 - val_loss: 0.0298
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9931 - loss: 0.0227 - val_accuracy: 0.9870 - val_loss: 0.0617
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9950 - loss: 0.0155 - val_accuracy: 0.9870 - val_loss: 0.0601
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9924 - loss: 0.0211 - val_accuracy: 0.9935 - val_loss: 0.0243
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9936 - loss: 0.0236 - val_accuracy: 0.9870 - val_loss: 0.0430
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9919 - loss: 0.0250 - val_accuracy: 0.9935 - val_loss: 0.0414
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9834 - loss: 0.0403 - val_accuracy: 0.9935 - val_loss: 0.0146
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9864 - loss: 0.0544 - val_accuracy: 0.9870 - val_loss: 0.0256
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9892 - loss: 0.0474 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9773 - loss: 0.0658 - val_accuracy: 0.9805 - val_loss: 0.0551
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9808 - loss: 0.0497 - val_accuracy: 0.9805 - val_loss: 0.0637
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9879 - loss: 0.0417 - val_accuracy: 0.9870 - val_loss: 0.0623
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9851 - loss: 0.0373 - val_accuracy: 0.9805 - val_loss: 0.0297
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9888 - loss: 0.0549 - val_accuracy: 0.9675 - val_loss: 0.0934
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9814 - loss: 0.0499 - val_accuracy: 1.0000 - val_loss: 0.0172
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9967 - loss: 0.0150 - val_accuracy: 0.9935 - val_loss: 0.0868
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9751 - loss: 0.1079 - val_accuracy: 0.9805 - val_loss: 0.1166
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9933 - loss: 0.0417 - val_accuracy: 0.9870 - val_loss: 0.0234
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9961 - loss: 0.0153 - val_accuracy: 0.9935 - val_loss: 0.0132
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9948 - loss: 0.0182 - val_accuracy: 0.9805 - val_loss: 0.0817
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9899 - loss: 0.0245 - val_accuracy: 0.9805 - val_loss: 0.0658
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9591 - loss: 0.2567
# 전체 데이터 정확도: 0.969072163105011
